# %%
# Welcome to your new notebook
# Type here in the cell editor to add code!
import sempy.fabric as fabric
# Out:
# StatementMeta(, c504b777-9d67-4574-9268-ea76ad0b2225, 3, Finished, Available, Finished)

# %%
fabric.list_workspaces()
# Out:
# StatementMeta(, c504b777-9d67-4574-9268-ea76ad0b2225, 4, Finished, Available, Finished)
#                                      Id  Is Read Only  \
# 0  7d748715-1b70-4e71-8860-b455ba18bb21         False
# 1  f95433a1-4031-4ad6-b674-b9a71834ea0e         False
# 2  7e198640-e770-46eb-b653-fa9e09eeadd4         False
# 3  29fa8608-7c01-4a50-ada1-3d8979109b64         False
# 4  b7f472bb-a634-48fc-aa12-2d92331bd535         False
#
#    Is On Dedicated Capacity                           Capacity Id  \
# 0                     False                                   NaN
# 1                      True  ab88342e-1386-435e-bd52-c67771f5c580
# 2                     False                                   NaN
# 3                      True  ab88342e-1386-435e-bd52-c67771f5c580
# 4                      True  ab88342e-1386-435e-bd52-c67771f5c580
#
#   Default Dataset Storage Format           Type  \
# 0                            NaN  AdminInsights
# 1                          Large      Workspace
# ...

# %%
fabric.list_datasets('f95433a1-4031-4ad6-b674-b9a71834ea0e')
# Out:
# StatementMeta(, c504b777-9d67-4574-9268-ea76ad0b2225, 5, Finished, Available, Finished)
#                      Dataset Name                            Dataset ID  \
# 0           Nike Sneaker Calendar  d903a240-43e5-4b80-8087-4a5b132a8c98
# 1  Sales & Returns Sample v201912  bb7219d9-1a97-4c41-8e58-5b7ed9db4d30
# 2                      test_model  4eefaf36-0d85-4d1c-8e2a-ddcc0cc4fa3e
#
#     Created Timestamp Last Update
# 0 2024-01-26 03:54:05         NaT
# 1 2019-09-27 17:48:58         NaT
# 2 2019-09-17 05:50:29         NaT

# %%
fabric.list_measures(workspace= "Sneaker Workspace", dataset="Sales & Returns Sample v201912")
# Out:
# StatementMeta(, c504b777-9d67-4574-9268-ea76ad0b2225, 6, Finished, Available, Finished)
#        Table Name                   Measure Name  \
# 0    Analysis DAX                      Net Sales
# 1    Analysis DAX                   Net Sales PM
# 2    Analysis DAX        Last 2 Months Net Sales
# 3    Analysis DAX             Net Sales Variance
# 4    Analysis DAX           Net Sales Variance %
# 5    Analysis DAX                     Units Sold
# 6    Analysis DAX                  Units Sold PM
# 7    Analysis DAX          Units Sold Variance %
# 8    Analysis DAX                        Returns
# 9    Analysis DAX                     Returns PM
# 10   Analysis DAX          Last 2 Months Returns
# 11   Analysis DAX               Returns Variance
# 12   Analysis DAX             Returns Variance %
# 13   Analysis DAX                 Units Returned
# 14   Analysis DAX              Units Returned PM
# 15   Analysis DAX      Units Returned Variance %
# ...

# %%
fabric.evaluate_measure(workspace= "Sneaker Workspace", dataset="Sales & Returns Sample v201912", measure="Net Sales")
# Out:
# StatementMeta(, c504b777-9d67-4574-9268-ea76ad0b2225, 7, Finished, Available, Finished)
#    Net Sales
# 0    1248013
