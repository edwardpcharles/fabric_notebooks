# %%
# %pip install semantic-link-labs

# %%
import sempy_labs as sl

dataset = 'customer car dealership clients' # Enter dataset name
new_dataset = 'customer car dealership clients2' # Enter dataset name
workspace = 'Developer' # Enter workspace name

model_bim = sl.get_semantic_model_definition(dataset=dataset, format='TMSL',workspace=workspace, return_dataframe = False)

sl.create_semantic_model_from_bim(dataset=new_dataset, bim_file=model_bim, workspace=workspace)
